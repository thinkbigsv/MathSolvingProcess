# %%
import pandas as pd
import numpy as np

# %%
domain_df = pd.read_csv('domain.csv')
domain_df.head()
# Out:
#   Domain1  Domain2       Domain3  Code
# 0     다항식  다항식의 연산       다항식의 정리     0
# 1     NaN      NaN   다항식의 덧셈, 뺄셈     1
# 2     NaN      NaN  다항식의 곱셈, 나눗셈     2
# 3     NaN      NaN          곱셈공식     3
# 4     NaN     인수분해   인수분해의 기본 공식    10

# %%
domain_df.fillna(method='ffill', inplace=True)
domain_df.head()
# Out:
#   Domain1  Domain2       Domain3  Code
# 0     다항식  다항식의 연산       다항식의 정리     0
# 1     다항식  다항식의 연산   다항식의 덧셈, 뺄셈     1
# 2     다항식  다항식의 연산  다항식의 곱셈, 나눗셈     2
# 3     다항식  다항식의 연산          곱셈공식     3
# 4     다항식     인수분해   인수분해의 기본 공식    10

# %%
class Treenode:
    def __init__(self, name, parent, level):
        self.name = name
        self.level = level
        self.parent = parent
        self.child = []
        self.aux = 0
        
    def __repr__(self):
        return 'level=' + str(self.level) + ' ' + self.name
    
    
class DomainTree:
    
    def __init__(self, df):
        self.tree = self.construct_tree(df)
    
    @staticmethod
    def construct_tree(df):
        tree = Treenode('Head', None, level=-1)
        for d1 in df.Domain1.unique().tolist():
            d1Node = Treenode(d1, tree, level=0)
            tree.child.append(d1Node)
            for d2 in df.Domain2[df.Domain1 == d1].unique().tolist():
                d2Node = Treenode(d2, d1Node, level=1)
                d1Node.child.append(d2Node)
                for d3 in df.Domain3[df.Domain1 == d1][df.Domain2 == d2].unique().tolist():
                    d3Node = Treenode(d3, d2Node, level=2)
                    d2Node.child.append(d3Node)
        return tree
    
    def gen_random_domain(self):
        dtree = self.tree
        d1 = np.random.randint(len(dtree.child))
        d2 = np.random.randint(len(dtree.child[d1].child))
        d3 = np.random.randint(len(dtree.child[d1].child[d2].child))
        return (dtree.child[d1].name, 
                dtree.child[d1].child[d2].name,
                dtree.child[d1].child[d2].child[d3].name)
    
    def traverse(self, func):
        '''
        level=2인 모든 노드들에 대해 func를 적용한다.
        '''
        
        for d1 in self.tree.child:
            for d2 in d1.child:
                for d3 in d2.child:
                    func(d3)
                    
    def set_aux(self, value):
        '''
        level=2인 모든 노드들의 aux에 value값을 넣어준다.
        '''
        def __set_aux(d):
            d.aux = value
        self.traverse(__set_aux)
        
    def set_aux_if(self, value, func):
        '''
        level=2인 노드들 중 func(node) 반환값이 참인 노드들의 aux에 value값을 넣어준다.
        '''
        def __set_aux_if(d):
            if func(d):
                d.aux = value
        self.traverse(__set_aux_if)
    
    def to_df(self):
        dtree_dict = {'domain1':[], 'domain2':[], 'domain3':[], 'aux':[]}
        dtree = self.tree
        for d1Node in dtree.child:
            for d2Node in d1Node.child:
                for d3Node in d2Node.child:
                    dtree_dict['domain1'].append(d1Node.name)
                    dtree_dict['domain2'].append(d2Node.name)
                    dtree_dict['domain3'].append(d3Node.name)
                    dtree_dict['aux'].append(d3Node.aux)
        return pd.DataFrame(dtree_dict, columns=['domain1', 'domain2', 'domain3', 'aux'])

# %%
class Problem:
    
    def __init__(self, pcode, domain, difficulty, error, answer):
        self.pcode = pcode
        self.domain = domain
        self.difficulty = difficulty
        self.error = error
        self.answer = answer
        
        self.depth = 3
        self.complexity = len(domain)
    
    def __repr__(self):
        repr_str = '{pcode=' + str(self.pcode) + '\n'
        repr_str = repr_str + 'domain=' + str(self.domain).replace('),', '),\n\t') + '\n'
        repr_str = repr_str + 'depth=' + str(self.depth) + '\n'
        repr_str = repr_str + 'complexity=' + str(self.complexity) + '\n'
        repr_str = repr_str + 'difficulty=' + str(self.difficulty) + '\n'
        repr_str = repr_str + 'error=' + str(self.error) + '\n'
        repr_str = repr_str + 'answer=' + str(self.answer) + '}\n'
        
        return repr_str
    
    @classmethod
    def gen_random_problem(cls, dtree, pcode=0):
        _complexity = np.random.randint(0, 100)
        if _complexity < 80:
            complexity = 1
        elif _complexity < 90:
            complexity = 2
        else:
            complexity = 3
            
        domain_list = []
        for i in range(complexity):
            domain_list.append(dtree.gen_random_domain())
        difficulty = np.random.randint(1, 101)
        answer = np.random.randint(1, 5)
        
        return cls(pcode, domain_list, difficulty, 0, answer)

# %%
domainTree = DomainTree(domain_df)
NUM_OF_PROBLEMS = 100
                        
problem_list = []
problem_dict = {'pcode':[], 'domain':[], 'depth':[], 'complexity':[], 'difficulty':[], 'error':[], 'answer':[]}
for i in range(NUM_OF_PROBLEMS):
    p = Problem.gen_random_problem(domainTree, i)
    problem_list.append(p)
    problem_dict['pcode'].append(p.pcode)
    problem_dict['domain'].append(p.domain)
    problem_dict['depth'].append(p.depth)
    problem_dict['complexity'].append(p.complexity)
    problem_dict['difficulty'].append(p.difficulty)
    problem_dict['error'].append(p.error)
    problem_dict['answer'].append(p.answer)
    
problem_df = pd.DataFrame(problem_dict, columns=['pcode', 'domain', 'depth', 'complexity', 'difficulty', 'error', 'answer'])
problem_df
# Out:
#     pcode                                             domain  depth  \
# 0       0  [(다항식, 인수분해, 인수분해의 기본 공식), (방정식과 부등식, 이차부등식과 연...      3
# 1       1                              [(경우의 수, 순열과 조합, 조합)]      3
# 2       2                             [(함수, 무리함수의 그래프, 무리식)]      3
# 3       3                              [(경우의 수, 순열과 조합, 조합)]      3
# 4       4                  [(도형의 방정식, 직선의 방정식, 두 직선의 위치 관계)]      3
# 5       5  [(다항식, 다항식의 연산, 다항식의 정리), (도형의 방정식, 도형의 이동, 평행...      3
# 6       6                         [(집합과 명제, 명제의 증명, 명제의 증명)]      3
# 7       7                          [(도형의 방정식, 도형의 이동, 평행이동)]      3
# 8       8                      [(집합과 명제, 명제의 증명, 절대부등식의 활용)]      3
# 9       9                       [(함수, 무리함수의 그래프, 무리함수의 그래프)]      3
# 10     10                 [(도형의 방정식, 직선의 방정식, 점과 직선 사이의 거리)]      3
# 11     11                  [(도형의 방정식, 원의 방정식, 원과 직선의 위치 관계)]      3
# 12     12                              [(경우의 수, 순열과 조합, 순열)]      3
# 13     13                         [(집합과 명제, 명제와 조건, 명제와 조건)]      3
# 14     14                 [(다항식, 항등식과 미정계수, 항등식의 성질과 미정계수법)]      3
# 15     15                      [(도형의 방정식, 평면좌표, 두 점 사이의 거리)]      3
# 16     16                      [(집합과 명제, 명제와 조건, 명제의 역과 대우)]      3
# 17     17                   [(다항식, 인수분해, 다항식의 최대공약수와 최소공배수)]      3
# 18     18            [(방정식과 부등식, 이차부등식과 연립이차부등식, 이차부등식의 해법)]      3
# 19     19  [(실수와 허수, 실수, 정수의 분류), (도형의 방정식, 직선의 방정식, 자취 문...      3
# 20     20                      [(도형의 방정식, 평면좌표, 두 점 사이의 거리)]      3
# 21     21                             [(실수와 허수, 실수, 정수의 분류)]      3
# 22     22                         [(집합과 명제, 명제의 증명, 명제의 증명)]      3
# 23     23                  [(도형의 방정식, 직선의 방정식, 두 직선의 위치 관계)]      3
# 24     24                 [(집합과 명제, 집합의 연산법칙, 유한집합의 원소의 개수)]      3
# 25     25                      [(집합과 명제, 명제의 증명, 절대부등식의 활용)]      3
# 26     26         [(방정식과 부등식, 이차방정식과 이차함수, 이차방정식과 이차함수의 관계)]      3
# 27     27                            [(다항식, 나머지 정리, 나머지 정리)]      3
# 28     28                             [(함수, 무리함수의 그래프, 무리식)]      3
# 29     29                            [(경우의 수, 경우의 수, 경우의 수)]      3
# ..    ...                                                ...    ...
# 70     70                      [(도형의 방정식, 평면좌표, 두 점 사이의 거리)]      3
# 71     71  [(경우의 수, 경우의 수, 경우의 수), (방정식과 부등식, 이차부등식과 연립이차...      3
# 72     72                             [(함수, 합성함수와 역함수, 역함수)]      3
# 73     73                           [(실수와 허수, 복소수, 허수와 복소수)]      3
# 74     74                              [(경우의 수, 순열과 조합, 조합)]      3
# 75     75                             [(함수, 합성함수와 역함수, 역함수)]      3
# 76     76                            [(다항식, 나머지 정리, 나머지 정리)]      3
# 77     77     [(경우의 수, 경우의 수, 경우의 수), (경우의 수, 경우의 수, 경우의 수)]      3
# 78     78                     [(다항식, 다항식의 연산, 다항식의 곱셈, 나눗셈)]      3
# 79     79  [(함수, 다항함수의 그래프, 이차함수의 그래프), (실수와 허수, 실수, 실수),...      3
# 80     80                           [(실수와 허수, 복소수, 허수와 복소수)]      3
# 81     81                      [(집합과 명제, 명제의 증명, 절대부등식의 활용)]      3
# 82     82                             [(실수와 허수, 실수, 정수의 분류)]      3
# 83     83                              [(경우의 수, 순열과 조합, 조합)]      3
# 84     84             [(방정식과 부등식, 최대와 최소, 제한된 범위에서의 최대와 최소)]      3
# 85     85                           [(실수와 허수, 복소수, 허수와 복소수)]      3
# 86     86                       [(함수, 무리함수의 그래프, 무리함수의 그래프)]      3
# 87     87                            [(경우의 수, 경우의 수, 경우의 수)]      3
# 88     88                    [(도형의 방정식, 직선의 방정식, 자취 문제(직선))]      3
# 89     89          [(방정식과 부등식, 이차방정식과 이차함수, 포물선과 직선의 위치 관계)]      3
# 90     90          [(방정식과 부등식, 이차부등식과 연립이차부등식, 연립이차부등식의 해법)]      3
# 91     91  [(다항식, 다항식의 연산, 다항식의 정리), (집합과 명제, 명제의 증명, 절대부...      3
# 92     92                          [(도형의 방정식, 도형의 이동, 평행이동)]      3
# 93     93                             [(집합과 명제, 집합, 집합과 원소)]      3
# 94     94                             [(집합과 명제, 집합, 집합과 원소)]      3
# 95     95  [(다항식, 항등식과 미정계수, 항등식의 성질과 미정계수법), (실수와 허수, 실수...      3
# 96     96                         [(다항식, 인수분해, 인수분해의 기본 공식)]      3
# 97     97                             [(함수, 유리함수의 그래프, 유리식)]      3
# 98     98                             [(실수와 허수, 실수, 정수의 분류)]      3
# 99     99  [(실수와 허수, 복소수, 복소수의 연산), (집합과 명제, 집합의 연산법칙, 집합...      3
#
#     complexity  difficulty  error  answer
# 0            2          58      0       4
# 1            1           2      0       2
# 2            1          99      0       1
# 3            1          17      0       4
# 4            1           8      0       1
# 5            2          53      0       1
# 6            1          35      0       4
# 7            1          70      0       1
# 8            1          46      0       4
# 9            1          92      0       1
# 10           1          69      0       3
# 11           1          27      0       2
# 12           1          16      0       2
# 13           1          35      0       2
# 14           1          61      0       3
# 15           1          67      0       3
# 16           1          90      0       3
# 17           1          93      0       3
# 18           1          90      0       1
# 19           2          75      0       4
# 20           1          91      0       2
# 21           1          17      0       2
# 22           1          71      0       3
# 23           1          12      0       1
# 24           1          41      0       1
# 25           1          60      0       4
# 26           1          95      0       3
# 27           1          26      0       3
# 28           1          42      0       1
# 29           1          21      0       3
# ..         ...         ...    ...     ...
# 70           1          89      0       1
# 71           2          31      0       2
# 72           1          51      0       3
# 73           1           1      0       1
# 74           1           4      0       1
# 75           1           2      0       4
# 76           1          26      0       4
# 77           2          99      0       2
# 78           1          98      0       1
# 79           3          42      0       3
# 80           1          55      0       1
# 81           1          68      0       3
# 82           1          59      0       4
# 83           1          54      0       3
# 84           1          52      0       1
# 85           1          73      0       1
# 86           1          80      0       1
# 87           1          11      0       3
# 88           1          54      0       2
# 89           1          44      0       2
# 90           1          24      0       3
# 91           2          26      0       3
# 92           1          45      0       1
# 93           1          51      0       2
# 94           1          33      0       2
# 95           3          53      0       4
# 96           1          66      0       1
# 97           1          88      0       3
# 98           1          28      0       1
# 99           2          75      0       2
#
# [100 rows x 7 columns]

# %%
class PSAgent:
    '''
    1. 도메인 별 정답률
    2. self report 컨셉
    3. difficulty 반영
    '''    
    def __init__(self, p_correct: float, p_self_report: tuple):               
        self.p_correct_tree = DomainTree(domain_df)
        self.set_aux(p_correct)
        self.p_self_report = p_self_report
        
    def solve(problem):
        pass
    
    def set_aux(self, value):
        self.p_correct_tree.set_aux(value)
        
    def set_aux_if(self, value, typefunc):
        self.p_correct_tree.set_aux_if(value, typefunc)
        
    @staticmethod
    def typefunc1(d):
        '''
        d: level 2(domain3)인 노드
        domain1에 '도형' 이라는 글자가 있으면 True 반환하는 함수
        '''
        if '도형' in d.parent.parent.name:
            return True

# %%
agent = PSAgent(0.8, (0.8, 0.4, 0.5))
agent.set_aux_if(0.5, PSAgent.typefunc1)

# %%
print(agent.p_self_report)
agent.p_correct_tree.to_df()
# Out:
# (0.8, 0.4, 0.5)
#      domain1           domain2              domain3  aux
# 0        다항식           다항식의 연산              다항식의 정리  0.8
# 1        다항식           다항식의 연산          다항식의 덧셈, 뺄셈  0.8
# 2        다항식           다항식의 연산         다항식의 곱셈, 나눗셈  0.8
# 3        다항식           다항식의 연산                 곱셈공식  0.8
# 4        다항식              인수분해          인수분해의 기본 공식  0.8
# 5        다항식              인수분해            기본 공식의 활용  0.8
# 6        다항식              인수분해    다항식의 최대공약수와 최소공배수  0.8
# 7        다항식         항등식과 미정계수       항등식의 성질과 미정계수법  0.8
# 8        다항식         항등식과 미정계수        다항식의 나눗셈과 항등식  0.8
# 9        다항식            나머지 정리               나머지 정리  0.8
# 10       다항식            나머지 정리      인수정리와 고차식의 인수분해  0.8
# 11    실수와 허수                실수                   실수  0.8
# 12    실수와 허수                실수               정수의 분류  0.8
# 13    실수와 허수                실수      제곱근, 세제곱근과 그 연산  0.8
# 14    실수와 허수                실수        무리수가 서로 같을 조건  0.8
# 15    실수와 허수               복소수              허수와 복소수  0.8
# 16    실수와 허수               복소수              복소수의 연산  0.8
# 17  방정식과 부등식         일차, 이차방정식            일차방정식의 해법  0.8
# 18  방정식과 부등식         일차, 이차방정식            이차방정식의 해법  0.8
# 19  방정식과 부등식        이차방정식의 판별식           이차방정식의 판별식  0.8
# 20  방정식과 부등식        이차방정식의 판별식              판별식의 활용  0.8
# 21  방정식과 부등식  이차방정식의 근과 계수의 관계     이차방정식의 근과 계수의 관계  0.8
# 22  방정식과 부등식  이차방정식의 근과 계수의 관계           이차방정식의 정수근  0.8
# 23  방정식과 부등식  이차방정식의 근과 계수의 관계        이차방정식의 실근의 부호  0.8
# 24  방정식과 부등식       이차방정식과 이차함수      이차방정식과 이차함수의 관계  0.8
# 25  방정식과 부등식       이차방정식과 이차함수       포물선과 직선의 위치 관계  0.8
# 26  방정식과 부등식       이차방정식과 이차함수         이차방정식의 근의 분리  0.8
# 27  방정식과 부등식            최대와 최소         이차함수의 최대와 최소  0.8
# 28  방정식과 부등식            최대와 최소     제한된 범위에서의 최대와 최소  0.8
# 29  방정식과 부등식            최대와 최소     판별식을 이용하는 최대와 최소  0.8
# ..       ...               ...                  ...  ...
# 53   도형의 방정식            원의 방정식             자취 문제(원)  0.5
# 54   도형의 방정식            도형의 이동                 평행이동  0.5
# 55   도형의 방정식            도형의 이동                 대칭이동  0.5
# 56    집합과 명제                집합               집합과 원소  0.8
# 57    집합과 명제                집합            집합의 포함 관계  0.8
# 58    집합과 명제                집합   합집합, 교집합, 여집합, 차집합  0.8
# 59    집합과 명제          집합의 연산법칙             집합의 연산법칙  0.8
# 60    집합과 명제          집합의 연산법칙         유한집합의 원소의 개수  0.8
# 61    집합과 명제            명제와 조건               명제와 조건  0.8
# 62    집합과 명제            명제와 조건            명제의 역과 대우  0.8
# 63    집합과 명제            명제와 조건           충분조건, 필요조건  0.8
# 64    집합과 명제            명제의 증명               명제의 증명  0.8
# 65    집합과 명제            명제의 증명            절대부등식의 증명  0.8
# 66    집합과 명제            명제의 증명            절대부등식의 활용  0.8
# 67        함수                함수                   함수  0.8
# 68        함수                함수              함수의 그래프  0.8
# 69        함수                함수                일대일대응  0.8
# 70        함수         합성함수와 역함수                 합성함수  0.8
# 71        함수         합성함수와 역함수                  역함수  0.8
# 72        함수         다항함수의 그래프            일차함수의 그래프  0.8
# 73        함수         다항함수의 그래프  절댓값 기호가 있는 방정식의 그래프  0.8
# 74        함수         다항함수의 그래프            이차함수의 그래프  0.8
# 75        함수         다항함수의 그래프        간단한 삼차함수의 그래프  0.8
# 76        함수         유리함수의 그래프                  유리식  0.8
# 77        함수         유리함수의 그래프            유리함수의 그래프  0.8
# 78        함수         무리함수의 그래프                  무리식  0.8
# 79        함수         무리함수의 그래프            무리함수의 그래프  0.8
# 80     경우의 수             경우의 수                경우의 수  0.8
# 81     경우의 수            순열과 조합                   순열  0.8
# 82     경우의 수            순열과 조합                   조합  0.8
#
# [83 rows x 4 columns]
