# %%
import pandas as pd
import numpy as np

# %%
domain_df = pd.read_csv('domain.csv')
domain_df.fillna(method='ffill', inplace=True)
domain_df.head()
# Out:
#   Domain1  Domain2       Domain3
# 0     다항식  다항식의 연산       다항식의 정리
# 1     다항식  다항식의 연산   다항식의 덧셈, 뺄셈
# 2     다항식  다항식의 연산  다항식의 곱셈, 나눗셈
# 3     다항식  다항식의 연산          곱셈공식
# 4     다항식     인수분해   인수분해의 기본 공식

# %%
class Treenode:
    def __init__(self, name, parent, level):
        self.name = name
        self.level = level
        self.parent = parent
        self.child = []
        self.aux = 0
        
    def __repr__(self):
        return 'level=' + str(self.level) + ' ' + self.name
    
    
class DomainTree:
    
    def __init__(self, df):
        self.tree = self.construct_tree(df)
    
    @staticmethod
    def construct_tree(df):
        tree = Treenode('Head', None, level=-1)
        for d1 in df.Domain1.unique().tolist():
            d1Node = Treenode(d1, tree, level=0)
            tree.child.append(d1Node)
            for d2 in df.Domain2[df.Domain1 == d1].unique().tolist():
                d2Node = Treenode(d2, d1Node, level=1)
                d1Node.child.append(d2Node)
                for d3 in df.Domain3[df.Domain1 == d1][df.Domain2 == d2].unique().tolist():
                    d3Node = Treenode(d3, d2Node, level=2)
                    d2Node.child.append(d3Node)
        return tree
    
    def gen_random_domain(self):
        dtree = self.tree
        d1 = np.random.randint(len(dtree.child))
        d2 = np.random.randint(len(dtree.child[d1].child))
        d3 = np.random.randint(len(dtree.child[d1].child[d2].child))
        return (dtree.child[d1].name, 
                dtree.child[d1].child[d2].name,
                dtree.child[d1].child[d2].child[d3].name)
    
    def traverse(self, func):
        '''
        level=2인 모든 노드들에 대해 func를 적용한다.
        '''
        
        for d1 in self.tree.child:
            for d2 in d1.child:
                for d3 in d2.child:
                    func(d3)
                    
    def set_aux(self, value):
        '''
        level=2인 모든 노드들의 aux에 value값을 넣어준다.
        '''
        def __set_aux(d):
            d.aux = value
        self.traverse(__set_aux)
        
    def set_aux_if(self, value, func):
        '''
        level=2인 노드들 중 func(node) 반환값이 참인 노드들의 aux에 value값을 넣어준다.
        '''
        def __set_aux_if(d):
            if func(d):
                d.aux = value
        self.traverse(__set_aux_if)
    
    def to_df(self):
        dtree_dict = {'domain1':[], 'domain2':[], 'domain3':[], 'aux':[]}
        dtree = self.tree
        for d1Node in dtree.child:
            for d2Node in d1Node.child:
                for d3Node in d2Node.child:
                    dtree_dict['domain1'].append(d1Node.name)
                    dtree_dict['domain2'].append(d2Node.name)
                    dtree_dict['domain3'].append(d3Node.name)
                    dtree_dict['aux'].append(d3Node.aux)
        return pd.DataFrame(dtree_dict, columns=['domain1', 'domain2', 'domain3', 'aux'])

# %%
class Problem:
    
    def __init__(self, pcode, domain, difficulty, error, answer):
        self.pcode = pcode
        self.domain = domain
        self.difficulty = difficulty
        self.error = error
        self.answer = answer
        
        self.depth = 3
        self.complexity = len(domain)
    
    def __repr__(self):
        repr_str = '{pcode=' + str(self.pcode) + '\n'
        repr_str = repr_str + 'domain=' + str(self.domain).replace('),', '),\n\t') + '\n'
        repr_str = repr_str + 'depth=' + str(self.depth) + '\n'
        repr_str = repr_str + 'complexity=' + str(self.complexity) + '\n'
        repr_str = repr_str + 'difficulty=' + str(self.difficulty) + '\n'
        repr_str = repr_str + 'error=' + str(self.error) + '\n'
        repr_str = repr_str + 'answer=' + str(self.answer) + '}\n'
        
        return repr_str
    
    @classmethod
    def gen_random_problem(cls, dtree, pcode=0):
        _complexity = np.random.randint(0, 100)
        if _complexity < 80:
            complexity = 1
        elif _complexity < 90:
            complexity = 2
        else:
            complexity = 3
            
        domain_list = []
        for i in range(complexity):
            domain_list.append(dtree.gen_random_domain())
        
        # error값을 알 수 없으므로 difficulty를 오답률로 사용한다.
        # complexity 올라갈 수록 difficulty올라간다고 가정
        if complexity == 1:
            difficulty = np.random.randint(5, 66)
        elif complexity == 2:
            difficulty = np.random.randint(20, 76)
        elif complexity == 3:
            difficulty = np.random.randint(40, 86)
        
        answer = np.random.randint(1, 5)
        
        return cls(pcode, domain_list, difficulty, 0, answer)

# %%
domainTree = DomainTree(domain_df)
NUM_OF_PROBLEMS = 100
                        
problem_list = []
problem_dict = {'pcode':[], 'domain':[], 'depth':[], 'complexity':[], 'difficulty':[], 'error':[], 'answer':[]}
for i in range(NUM_OF_PROBLEMS):
    p = Problem.gen_random_problem(domainTree, i)
    problem_list.append(p)
    problem_dict['pcode'].append(p.pcode)
    problem_dict['domain'].append(p.domain)
    problem_dict['depth'].append(p.depth)
    problem_dict['complexity'].append(p.complexity)
    problem_dict['difficulty'].append(p.difficulty)
    problem_dict['error'].append(p.error)
    problem_dict['answer'].append(p.answer)
    
problem_df = pd.DataFrame(problem_dict, columns=['pcode', 'domain', 'depth', 'complexity', 'difficulty', 'error', 'answer'])
problem_df.head()
# Out:
#    pcode                                             domain  depth  \
# 0      0  [(방정식과 부등식, 일차, 이차방정식, 일차방정식의 해법), (집합과 명제, 집합...      3
# 1      1                      [(집합과 명제, 명제의 증명, 절대부등식의 활용)]      3
# 2      2                  [(다항식, 항등식과 미정계수, 다항식의 나눗셈과 항등식)]      3
# 3      3  [(실수와 허수, 실수, 실수), (경우의 수, 순열과 조합, 순열), (집합과 명...      3
# 4      4                            [(경우의 수, 경우의 수, 경우의 수)]      3
#
#    complexity  difficulty  error  answer
# 0           3          59      0       1
# 1           1          55      0       4
# 2           1          38      0       1
# 3           3          80      0       4
# 4           1          29      0       1

# %%
class PSAgent:
    '''
    1. 도메인 별 정답률
    2. self report 컨셉
    3. difficulty 반영
    '''    
    def __init__(self):
        self.p_domain = DomainTree(domain_df).to_df()
        self.p_domain.rename(columns={'aux': 'correct'}, inplace=True)
        self.p_domain['report1'] = self.p_domain['correct'].copy()
        self.p_domain['report2'] = self.p_domain['correct'].copy()
        self.p_domain['report3'] = self.p_domain['correct'].copy()
        
        self.complexity_weak = 0.9  # complexity 1 올라갈 때 감소하는 정답률
        

    def set_p_domain(self, domain1_name: str, values: tuple):
        '''
        domain1_name: e.g. '다항식', type=str
        values:  e.g. (0.8, 0.4, 0.5, 0.3), type=tuple (or list)
        
        domain1에 domain1_name 글자가 있으면 correct, report1, report2, report3
        를 value로 설정하는 함수
        '''
        filtered_rows = self.p_domain['domain1'].str.contains(domain1_name)
        self.p_domain.loc[filtered_rows, 'correct'] = values[0]
        self.p_domain.loc[filtered_rows, 'report1'] = values[1]
        self.p_domain.loc[filtered_rows, 'report2'] = values[2]
        self.p_domain.loc[filtered_rows, 'report3'] = values[3]
        
    def solve(problem):
        pass

# %%
agent = PSAgent()
agent.set_p_domain('다항식', (0.1, 0.2, 0.3, 0.4))
agent.p_domain
# Out:
#      domain1           domain2              domain3  correct  report1  \
# 0        다항식           다항식의 연산              다항식의 정리      0.1      0.2
# 1        다항식           다항식의 연산          다항식의 덧셈, 뺄셈      0.1      0.2
# 2        다항식           다항식의 연산         다항식의 곱셈, 나눗셈      0.1      0.2
# 3        다항식           다항식의 연산                 곱셈공식      0.1      0.2
# 4        다항식              인수분해          인수분해의 기본 공식      0.1      0.2
# 5        다항식              인수분해            기본 공식의 활용      0.1      0.2
# 6        다항식              인수분해    다항식의 최대공약수와 최소공배수      0.1      0.2
# 7        다항식         항등식과 미정계수       항등식의 성질과 미정계수법      0.1      0.2
# 8        다항식         항등식과 미정계수        다항식의 나눗셈과 항등식      0.1      0.2
# 9        다항식            나머지 정리               나머지 정리      0.1      0.2
# 10       다항식            나머지 정리      인수정리와 고차식의 인수분해      0.1      0.2
# 11    실수와 허수                실수                   실수      0.0      0.0
# 12    실수와 허수                실수               정수의 분류      0.0      0.0
# 13    실수와 허수                실수      제곱근, 세제곱근과 그 연산      0.0      0.0
# 14    실수와 허수                실수        무리수가 서로 같을 조건      0.0      0.0
# 15    실수와 허수               복소수              허수와 복소수      0.0      0.0
# 16    실수와 허수               복소수              복소수의 연산      0.0      0.0
# 17  방정식과 부등식         일차, 이차방정식            일차방정식의 해법      0.0      0.0
# 18  방정식과 부등식         일차, 이차방정식            이차방정식의 해법      0.0      0.0
# 19  방정식과 부등식        이차방정식의 판별식           이차방정식의 판별식      0.0      0.0
# 20  방정식과 부등식        이차방정식의 판별식              판별식의 활용      0.0      0.0
# 21  방정식과 부등식  이차방정식의 근과 계수의 관계     이차방정식의 근과 계수의 관계      0.0      0.0
# 22  방정식과 부등식  이차방정식의 근과 계수의 관계           이차방정식의 정수근      0.0      0.0
# 23  방정식과 부등식  이차방정식의 근과 계수의 관계        이차방정식의 실근의 부호      0.0      0.0
# 24  방정식과 부등식       이차방정식과 이차함수      이차방정식과 이차함수의 관계      0.0      0.0
# 25  방정식과 부등식       이차방정식과 이차함수       포물선과 직선의 위치 관계      0.0      0.0
# 26  방정식과 부등식       이차방정식과 이차함수         이차방정식의 근의 분리      0.0      0.0
# 27  방정식과 부등식            최대와 최소         이차함수의 최대와 최소      0.0      0.0
# 28  방정식과 부등식            최대와 최소     제한된 범위에서의 최대와 최소      0.0      0.0
# 29  방정식과 부등식            최대와 최소     판별식을 이용하는 최대와 최소      0.0      0.0
# ..       ...               ...                  ...      ...      ...
# 53   도형의 방정식            원의 방정식             자취 문제(원)      0.0      0.0
# 54   도형의 방정식            도형의 이동                 평행이동      0.0      0.0
# 55   도형의 방정식            도형의 이동                 대칭이동      0.0      0.0
# 56    집합과 명제                집합               집합과 원소      0.0      0.0
# 57    집합과 명제                집합            집합의 포함 관계      0.0      0.0
# 58    집합과 명제                집합   합집합, 교집합, 여집합, 차집합      0.0      0.0
# 59    집합과 명제          집합의 연산법칙             집합의 연산법칙      0.0      0.0
# 60    집합과 명제          집합의 연산법칙         유한집합의 원소의 개수      0.0      0.0
# 61    집합과 명제            명제와 조건               명제와 조건      0.0      0.0
# 62    집합과 명제            명제와 조건            명제의 역과 대우      0.0      0.0
# 63    집합과 명제            명제와 조건           충분조건, 필요조건      0.0      0.0
# 64    집합과 명제            명제의 증명               명제의 증명      0.0      0.0
# 65    집합과 명제            명제의 증명            절대부등식의 증명      0.0      0.0
# 66    집합과 명제            명제의 증명            절대부등식의 활용      0.0      0.0
# 67        함수                함수                   함수      0.0      0.0
# 68        함수                함수              함수의 그래프      0.0      0.0
# 69        함수                함수                일대일대응      0.0      0.0
# 70        함수         합성함수와 역함수                 합성함수      0.0      0.0
# 71        함수         합성함수와 역함수                  역함수      0.0      0.0
# 72        함수         다항함수의 그래프            일차함수의 그래프      0.0      0.0
# 73        함수         다항함수의 그래프  절댓값 기호가 있는 방정식의 그래프      0.0      0.0
# 74        함수         다항함수의 그래프            이차함수의 그래프      0.0      0.0
# 75        함수         다항함수의 그래프        간단한 삼차함수의 그래프      0.0      0.0
# 76        함수         유리함수의 그래프                  유리식      0.0      0.0
# 77        함수         유리함수의 그래프            유리함수의 그래프      0.0      0.0
# 78        함수         무리함수의 그래프                  무리식      0.0      0.0
# 79        함수         무리함수의 그래프            무리함수의 그래프      0.0      0.0
# 80     경우의 수             경우의 수                경우의 수      0.0      0.0
# 81     경우의 수            순열과 조합                   순열      0.0      0.0
# 82     경우의 수            순열과 조합                   조합      0.0      0.0
#
#     report2  report3
# 0       0.3      0.4
# 1       0.3      0.4
# 2       0.3      0.4
# 3       0.3      0.4
# 4       0.3      0.4
# 5       0.3      0.4
# 6       0.3      0.4
# 7       0.3      0.4
# 8       0.3      0.4
# 9       0.3      0.4
# 10      0.3      0.4
# 11      0.0      0.0
# 12      0.0      0.0
# 13      0.0      0.0
# 14      0.0      0.0
# 15      0.0      0.0
# 16      0.0      0.0
# 17      0.0      0.0
# 18      0.0      0.0
# 19      0.0      0.0
# 20      0.0      0.0
# 21      0.0      0.0
# 22      0.0      0.0
# 23      0.0      0.0
# 24      0.0      0.0
# 25      0.0      0.0
# 26      0.0      0.0
# 27      0.0      0.0
# 28      0.0      0.0
# 29      0.0      0.0
# ..      ...      ...
# 53      0.0      0.0
# 54      0.0      0.0
# 55      0.0      0.0
# 56      0.0      0.0
# 57      0.0      0.0
# 58      0.0      0.0
# 59      0.0      0.0
# 60      0.0      0.0
# 61      0.0      0.0
# 62      0.0      0.0
# 63      0.0      0.0
# 64      0.0      0.0
# 65      0.0      0.0
# 66      0.0      0.0
# 67      0.0      0.0
# 68      0.0      0.0
# 69      0.0      0.0
# 70      0.0      0.0
# 71      0.0      0.0
# 72      0.0      0.0
# 73      0.0      0.0
# 74      0.0      0.0
# 75      0.0      0.0
# 76      0.0      0.0
# 77      0.0      0.0
# 78      0.0      0.0
# 79      0.0      0.0
# 80      0.0      0.0
# 81      0.0      0.0
# 82      0.0      0.0
#
# [83 rows x 7 columns]
