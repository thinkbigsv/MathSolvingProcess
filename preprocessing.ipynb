# %%
import pandas as pd

# %%
df = pd.read_csv('problemset.csv', encoding='utf-8')
df
# Out:
#           pcode                  domain1                   domain2  \
# 0   h2_1503_a01                      다항식                   다항식의 연산
# 1   h2_1503_a03                 방정식과 부등식                     이차방정식
# 2   h2_1503_a05                   집합과 명제                 집합의 뜻과 표현
# 3   h2_1503_a06                      다항식                항등식과 나머지정리
# 4   h2_1503_a07                       함수                        함수
# 5   h2_1503_a08                  도형의 방정식                   직선의 방정식
# 6   h2_1503_a09  집합과 명제 / 방정식과 부등식 / 다항식      명제 / 여러가지 부등식 / 인수분해
# 7   h2_1503_a10                       함수                        함수
# 8   h2_1503_a11      방정식과 부등식 / 방정식과 부등식       여러가지 부등식 / 여러가지 방정식
# 9   h2_1503_a12                 방정식과 부등식                  여러가지 방정식
# 10  h2_1503_a13                 방정식과 부등식                     이차방정식
# 11  h2_1503_a14                 방정식과 부등식                     이차방정식
# 12  h2_1503_a15                다항식 / 다항식   항등식과 나머지정리 / 항등식과 나머지정리
# 13  h2_1503_a16             함수 / 도형의 방정식             유리함수 / 도형의 이동
# 14  h2_1503_a18                  도형의 방정식                    도형의 이동
# 15  h2_1503_a19                  도형의 방정식                    원의 방정식
# 16  h2_1503_a20           다항식 / 방정식과 부등식  항등식과 나머지정리 / 이차방정식과 이차함수
# 17  h2_1503_a21                  도형의 방정식                    원의 방정식
# 18  h2_1803_b02                      다항식                   다항식의 연산
# 19  h2_1803_b03                 방정식과 부등식                       복소수
# 20  h2_1803_b04                  도형의 방정식                      평면좌표
# 21  h2_1803_b05                       함수                        함수
# 22  h2_1803_b06                      다항식                항등식과 나머지정리
# 23  h2_1803_b07                      다항식                항등식과 나머지정리
# 24  h2_1803_b08                       함수                      무리함수
# 25  h2_1803_b09                 방정식과 부등식               이차방정식과 이차함수
# 26  h2_1803_b10                 방정식과 부등식                  여러가지 방정식
# 27  h2_1803_b11          집합과 명제/방정식과 부등식        집합의 뜻과 표현/여러가지 부등식
# 28  h2_1803_b12          도형의 방정식/도형의 방정식            직선의 방정식/원의 방정식
# 29  h2_1803_b13                       함수                        함수
# ..          ...                      ...                       ...
# 48  h2_1603_b13               도형의 방정식/함수               도형의 이동/유리함수
# 49  h2_1603_b14                    함수/로그           유리함수/로그 밑 변환 공식
# 50  h2_1603_b15                   다항식/함수       인수정리/이차함수와 직선의 위치관계
# 51  h2_1603_b16                       수열                   수학적 귀납법
# 52  h2_1603_b17                      다항식                      인수분해
# 53  h2_1603_b18          도형의 방정식/도형의 방정식              평면좌표/직선의 방정식
# 54  h2_1603_b19                       수열                     수열의 합
# 55  h2_1603_b20                집합과 명제/함수             집합의 정의/함수의 정의
# 56  h2_1603_b21          도형의 방정식/도형의 방정식              평면좌표/직선의 방정식
# 57  h2_1703_b01                      다항식                   다항식의 연산
# 58  h2_1703_b02                  도형의 방정식                      평면좌표
# 59  h2_1703_b03                 방정식과 부등식                     이차방정식
# 60  h2_1703_b04                 방정식과 부등식                       복소수
# 61  h2_1703_b05                       함수                      무리함수
# 62  h2_1703_b06                   지수와 로그                        로그
# 63  h2_1703_b07                   집합과 명제                        집합
# 64  h2_1703_b08                      다항식               항등식과 나머지 정리
# 65  h2_1703_b09                   집합과 명제                    집합의 연산
# 66  h2_1703_b10                       수열                등차수열과 등비수열
# 67  h2_1703_b11                 방정식과 부등식                  여러가지 방정식
# 68  h2_1703_b12                      다항식                      인수분해
# 69  h2_1703_b13                 방정식과 부등식                  여러가지 부등식
# 70  h2_1703_b14                      다항식                      인수분해
# 71  h2_1703_b15                    함수/수열           유리함수/등차수열과 등비수열
# 72  h2_1703_b16              지수와 로그/거듭제곱                        로그
# 73  h2_1703_b17           수열/대수(자연수, 정수)                   수학적 귀납법
# 74  h2_1703_b18                  도형의 방정식           원의 방정식/ 직선의 방정식
# 75  h2_1703_b19               함수/도형의 방정식              유리함수/직선의 방정식
# 76  h2_1703_b20                    함수/명제               합성함수/참거짓 판별
# 77  h2_1703_b21                   수열/다항식        등차수열과 등비수열/다항식의 연산
#
#                                               domain3  depth  complexity  \
# 0                                              덧셈과 뺄셈      3           1
# 1                                           근과 계수의 관계      3           1
# 2                                            서로 같은 집합      3           1
# 3                                               계수비교법      3           1
# 4                                             역함수의 정의      3           1
# 5                                        선문의 내분점과 외분점      3           1
# 6                                  충분조건, 필요조건, 필요충분조건      3           3
# 7                                               일대일대응      3           1
# 8                                                   0      2           2
# 9                                           근과 계수의 관계      3           1
# 10                                  이차함수의 그래프와 직섬의 교점      3           1
# 11                                          근과 계수의 관계      3           1
# 12  나머지정리 : 일차식으로 나눌 때의 나머지 / 나머지정리 : 이차식으로 나눌 때의 나머지      3           1
# 13                           유리함수의 그래프의 성질 / 평행이동의 활용      3           2
# 14                                            점의 대칭이동      3           1
# 15                                원과 직선의 위치 관계 : 접할 때      3           1
# 16                                   미정계수 구하기 : 계수비교법      3           2
# 17                    원과 직선의 위치 관계 : 서로 다른 두 점에서 만날 때      3           1
# 18                                            다항식의 뺄셈      3           1
# 19                                        복소수의 덧셈과 곱셈      3           1
# 20                                            선분의 내분점      3           1
# 21                                          합성함수의 함수값      3           1
# 22                                                항등식      3           1
# 23                                              나머지정리      3           1
# 24                                     무리함수 그래프의 평행이동      3           1
# 25                                          이차함수의 최솟값      3           1
# 26                                         연립이차방정식의 해      3           1
# 27                                        진리집합 사이의 관계      3           2
# 28                                       /원과 직선사이의 관계      3           2
# 29                                              함수의 뜻      3           1
# ..                                                ...    ...         ...
# 48                                   도형의 대칭/유리함수의 점근선      3           2
# 49                                           /상용로그 계산      3           2
# 50                                        이차함수 최댓값 계산      3           2
# 51                                              수열의 합      3           1
# 52                                                  0      2           1
# 53                                   무게중심/점과 직선 사이 거리      3           2
# 54                                              수열 추론      3           1
# 55                                 ‘모든’과 ‘어떤’의 의미/역함수      3           2
# 56             점의 내분, 점과 점 사이의 거리/기울기의 성질, 직선 방정식 세우기      4           2
# 57                                                  0      2           1
# 58                                                  0      2           1
# 59                                                  0      2           1
# 60                                                  0      2           1
# 61                                          무리함수의 역함수      3           2
# 62                                                  0      2           1
# 63                                                  0      2           1
# 64                                                  0      2           1
# 65                                             실생활 문제      3           1
# 66                                               등차수열      3           1
# 67                                              열립방정식      3           1
# 68                                                  0      2           2
# 69                                              이차부등식      3           2
# 70                                               곱셈공식      3           2
# 71                                               등비수열      3           2
# 72                                                  0      2           2
# 73                                                  0      2           2
# 74                                                  0      3           2
# 75                                                  0      4           2
# 76                                              일대일대응      3           2
# 77                                               등차수열      3           2
#
#     difficulty  error  answer
# 0          5.0    0.0       3
# 1          8.0    0.0       4
# 2          7.0    0.0       5
# 3         10.0    0.0       5
# 4          8.0    0.0       3
# 5         21.0    0.0       4
# 6         15.0    0.0       2
# 7         18.0    0.0       1
# 8         34.0    0.0       4
# 9         18.0    0.0       3
# 10         9.0    0.0       1
# 11        27.0    0.0       3
# 12        20.0    0.0       1
# 13        25.0    0.0       5
# 14        16.0    0.0       2
# 15        18.0    0.0       4
# 16        29.0    0.0       5
# 17        27.0    0.0       2
# 18        10.0    0.0       5
# 19        10.0    0.0       4
# 20        10.0    0.0       4
# 21        20.0    0.0       2
# 22        20.0    0.0       1
# 23        20.0    0.0       2
# 24        20.0    0.0       3
# 25        30.0    0.0       5
# 26        30.0    0.0       2
# 27        30.0    0.0       3
# 28        40.0    0.0       1
# 29        20.0    0.0       3
# ..         ...    ...     ...
# 48        25.0    0.0       4
# 49        35.0    0.0       5
# 50        40.0    0.0       1
# 51        40.0    0.0       4
# 52        42.0    0.0       2
# 53        40.0    0.0       1
# 54        46.0    0.0       3
# 55        57.0    0.0       5
# 56        59.0    0.0       5
# 57         5.0    0.0       4
# 58         5.0    0.0       3
# 59         6.0    0.0       5
# 60         6.0    0.0       1
# 61        10.0    0.0       4
# 62         5.0    0.0       2
# 63        10.0    0.0       3
# 64        10.0    0.0       1
# 65        10.0    0.0       5
# 66        10.0    0.0       4
# 67        10.0    0.0       2
# 68        10.0    0.0       1
# 69        10.0    0.0       3
# 70        14.0    0.0       2
# 71        15.0    0.0       5
# 72        15.0    0.0       4
# 73        15.0    0.0       2
# 74        20.0    0.0       1
# 75        20.0    0.0       5
# 76        25.0    0.0       3
# 77        25.0    0.0       2
#
# [78 rows x 9 columns]

# %%
out_of_h1 = df[df['domain1'].str.match('지수')]
out_of_h1
# Out:
#           pcode      domain1 domain2 domain3  depth  complexity  difficulty  \
# 38  h2_1603_b03       지수와 로그  지수의 연산       0      2           1         4.0
# 62  h2_1703_b06       지수와 로그      로그       0      2           1         5.0
# 72  h2_1703_b16  지수와 로그/거듭제곱      로그       0      2           2        15.0
#
#     error  answer
# 38    0.0       3
# 62    0.0       2
# 72    0.0       4

# %%
df.drop(out_of_h1.index, inplace=True)

# %%
df.domain1.describe()
# Out:
# count           75
# unique          28
# top       방정식과 부등식
# freq            13
# Name: domain1, dtype: object

# %%
df.domain2.describe()
# Out:
# count        75
# unique       49
# top       이차방정식
# freq          4
# Name: domain2, dtype: object

# %%
df.domain3.describe()
# Out:
# count     75
# unique    51
# top        0
# freq      21
# Name: domain3, dtype: object
